# %% [markdown]
# ### Imports

# %%
# imports
from feature_processor import *
from var import *

# %% [markdown]
# ### Feature processing

# %%
# path to data folder
path = '/home/romain/clean_codes/4_var'
# name of file containing monthly features
feature_file = 'features.csv'
# name of file containing the information about monthly data
information_file = 'information.csv'

# %%
# declare feature processor
fp = FeatureProcessor(path, feature_file, information_file)
# load, process, and plot
fp.data_loader()
fp.data_processor()
fp.plot_processed_data()

# %%
# overview of processed features in dataframe
features = fp.processed_features
features.head(6)
# Out:
#             business_confidence_index  industrial_production  business_sales  \
# date
# 1993-09-30                   -0.01763               1.174819        1.526916
# 1993-12-31                    2.23292               4.516257        4.820045
# 1994-03-31                    1.67461               3.695746        6.177410
# 1994-06-30                    1.01670               5.385214        5.706889
# 1994-09-30                    0.45180               3.808076        7.841516
# 1994-12-31                   -0.23480               6.156890        8.395498
#
#             new_residential_sales  unemployment_rate  weekly_hours       cpi  \
# date
# 1993-09-30              10.375088               -0.8      0.489573 -0.896798
# 1993-12-31               8.713100               -0.5      1.212714 -0.140156
# 1994-03-31               3.742247               -0.2     -0.009381 -0.671583
# 1994-06-30               8.908318               -1.1      3.377695 -0.459493
# 1994-09-30              18.823001               -0.6     -0.719138  1.381100
# 1994-12-31               7.938450               -1.1      0.719138 -0.734759
#
#             bank_assets  federal_funds_rate  quarterly_gdp
# date
# 1993-09-30     6.056690                0.18       0.477315
# 1993-12-31     1.243932               -0.21       1.360113
# 1994-03-31     5.767958                0.67       0.970216
# 1994-06-30     3.522080                2.18       1.355046
# 1994-09-30     5.161621                1.64       0.584515
# 1994-12-31     3.148223                2.04       1.145524

# %% [markdown]
# ### VAR model

# %%
# number of lags
p = 2

# %%
# declare VAR model
var = Vector_Autoregression(feature_dataframe = features)
# generate regressors
var.regressors(p)
# train the model
var.train()

# %% [markdown]
# ### predictions

# %%
# number of periods ahead to forecast (in quarters)
h = 12
# generate predictions
var.forecast(h)
# plot predictions
var.plot_forecast()
